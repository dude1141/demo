-- %%
%sql
USE CATALOG hive_metastore;

-- %%
%sql
CREATE TABLE managed_default
  (width INT, length INT, height INT)
LOCATION 'dbfs:/mnt/demoworkspace/external_default';

INSERT INTO managed_default
VALUES (3 INT, 2 INT, 1 INT);

-- %%
describe extended managed_default;

-- %%
%sql
CREATE TABLE IF NOT EXISTS emp
  (id INT, name STRING, sal DOUBLE);

INSERT INTO emp
VALUES (3 , 'arya' , 1000.12 );

-- %%
INSERT INTO emp
VALUES (4 , 'earya' , 2000.12 );

-- %%
select * from emp;

-- %%
describe detail emp;

-- %%
%fs ls 'dbfs:/user/hive/warehouse/emp'

-- %%
%fs ls 'dbfs:/user/hive/warehouse/emp/_delta_log/'

-- %%
optimize emp
zorder by id

-- %%
VACUUM emp retain 0 hours;

-- %%
SET spark.databricks.delta.retentionDurationCheck.enabled=false;
